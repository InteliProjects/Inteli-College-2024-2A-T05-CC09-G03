# %% [markdown]
# # Extração e agrupamento de labels

# %% [markdown]
# ## Conexão com o Drive para acessar os dados
#
# Esta etapa é necessária para permitir que o Colab acesse os arquivos armazenados no Google Drive.

# %%
# Conexão com o drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Importação das bibliotecas
#
# Importaremos as bibliotecas necessárias para o processamento das imagens e manipulação dos dados:
#
# - **os**: Para interagir com o sistema operacional, listando arquivos e manipulando caminhos.
# - **cv2 (OpenCV)**: Utilizada para leitura, escrita e manipulação de imagens.
# - **numpy (np)**: Biblioteca para manipulação eficiente de arrays e operações matemáticas.
# - **h5py**: Para salvar e carregar arquivos no formato HDF5, ideal para grandes volumes de dados.
# - **google.colab.drive**: Permite montar o Google Drive no Colab para acessar arquivos armazenados na nuvem.

# %%
import os
import h5py
import cv2
import numpy as np

# %% [markdown]
# ## Extração dos dados

# %% [markdown]
# ### Caminho para as pastas
#
# Este trecho de código define um dicionário `paths` que contém os caminhos para as pastas de imagens X e Y de cada grupo (G1, G2, G3, G4) organizados por data.

# %%
paths = {
    'G1': {
        '01-08-2024': {
            'X': '/content/drive/MyDrive/CattleImageRepository/G1/01-08-2024/X',
            'Y': '/content/drive/MyDrive/CattleImageRepository/G1/01-08-2024/y'
        },
        '08-08-2024': {
            'X': '/content/drive/MyDrive/CattleImageRepository/G1/08-08-2024/X',
            'Y': '/content/drive/MyDrive/CattleImageRepository/G1/08-08-2024/Y'
        }
    },
    'G2': {
        '06-08-2024_Video_1': {
            'X': '/content/drive/MyDrive/CattleImageRepository/G2/06-08/Video_1/X',
            'Y': '/content/drive/MyDrive/CattleImageRepository/G2/06-08/Video_1/Y'
        },
        '29-07-2024': {
            'X': '/content/drive/MyDrive/CattleImageRepository/G2/29-07/00000000196000400/X',
            'Y': '/content/drive/MyDrive/CattleImageRepository/G2/29-07/00000000196000400/Y'
        }
    },
    'G3': {
        '30-07-2024': {
            'X': '/content/drive/MyDrive/CattleImageRepository/G3/30-07/termica/x',
            'Y': '/content/drive/MyDrive/CattleImageRepository/G3/30-07/termica/y'
        }
    },
    'G4': {
        '02-08-2024': {
            'X': '/content/drive/MyDrive/CattleImageRepository/G4/02-08/X',
            'Y': '/content/drive/MyDrive/CattleImageRepository/G4/02-08/Y'
        }
    },
}

# %% [markdown]
# ### Função para processar as imagens dos grupos, sem condições
#
# Essa função serve para carregar as imagens das pastas de cada grupo, sem aplicar nenhuma regra específica para considerar os arquivos, a fim de analisar o shape das pastas correspondentes de X e Y, verificando se possuem a mesma quantidade de arquivos ou se está corrompida de alguma forma.

# %%
def load_images_from_folder(folder, target_size=(128, 128)):
  images = []
  for filename in os.listdir(folder):

    img = cv2.imread(os.path.join(folder, filename))
    if img is not None:
        if target_size:
            img = cv2.resize(img, target_size)
        images.append(img)
  return np.array(images)

# %% [markdown]
# #### Carregamento das imagens dos grupos
#
# O código a seguir carrega as imagens de todas as pastas que estão destacadas na variável `paths`.

# %%
group_data = {}

for group, dates in paths.items():
    group_data[group] = {}
    for date, folders in dates.items():
        X_path = folders['X']
        Y_path = folders['Y']

        X_images = load_images_from_folder(X_path)
        Y_images = load_images_from_folder(Y_path)

        group_data[group][date] = {
            'X': X_images,
            'Y': Y_images
        }

# %% [markdown]
# #### Verificação dos shapes das pastas sem condições

# %%
for group, data in group_data.items():
    for date, images in data.items():
        print(f"Grupo: {group}, Data: {date}, X shape: {images['X'].shape}, Y shape: {images['Y'].shape}")
# Out:
# Grupo: G1, Data: 01-08-2024, X shape: (763, 224, 224, 3), Y shape: (745, 224, 224, 3)
# Grupo: G1, Data: 08-08-2024, X shape: (615, 224, 224, 3), Y shape: (829, 224, 224, 3)
# Grupo: G2, Data: 06-08-2024_Video_1, X shape: (856, 224, 224, 3), Y shape: (856, 224, 224, 3)
# Grupo: G2, Data: 29-07-2024, X shape: (325, 224, 224, 3), Y shape: (342, 224, 224, 3)
# Grupo: G3, Data: 30-07-2024, X shape: (724, 224, 224, 3), Y shape: (724, 224, 224, 3)
# Grupo: G4, Data: 02-08-2024, X shape: (843, 224, 224, 3), Y shape: (843, 224, 224, 3)

# %% [markdown]
# É possível verificar claramente que há distorção nas pastas do G1 e do G2, em quesitos de quantidade de arquivos nas pastas X e Y. Portanto, precisamos aplicar condições para assegurar que apenas os arquivos X e Y correspondentes sejam considerados.

# %% [markdown]
# ### Funções para processar os arquivos de cada grupo, com condições
#
# Essas funções servem para carregar as imagens das pastas de cada grupo, aplicando as regras específicas para garantir que apenas os arquivos correspondentes de X e Y sejam considerados. As funções estão separadas por grupo devido às diferenças de nomenclatura e organização de arquivos.

# %%
# Processamento para cada grupo
X_data, Y_data = [], []

# %% [markdown]
# #### Função para processar arquivos do G1
#
# Esta função carrega os arquivos X e Y do Grupo 1, verificando as variações de nomenclatura nos arquivos Y (`_x_y` ou `_y`).

# %%
def process_g1(x_dir, y_dir):
    X_data, Y_data = [], []
    x_files = [f for f in os.listdir(x_dir) if not 'overlay' in f]
    y_files = [f for f in os.listdir(y_dir) if not 'overlay' in f]

    for x_file in x_files:
        base_name = x_file.rsplit('_x', 1)[0]
        y_file_1 = base_name + '_x_y.png'
        y_file_2 = base_name + '_y.png'

        if y_file_1 in y_files:
            y_file = y_file_1
        elif y_file_2 in y_files:
            y_file = y_file_2
        else:
            print(f"Corresponding Y file not found for {x_file}. Skipping...")
            continue

        x_img = cv2.imread(os.path.join(x_dir, x_file))
        y_img = cv2.imread(os.path.join(y_dir, y_file))
        X_data.append(x_img)
        Y_data.append(y_img)

    print(f"Total processed for group G1: {len(X_data)} pairs.")
    return np.array(X_data), np.array(Y_data)

# %% [markdown]
# Nesta célula, processamos as imagens do Grupo 1. Para cada data no Grupo 1, a função processa as imagens de X e Y, garantindo que haja correspondência entre elas. Os dados correspondentes são armazenados em arrays numpy. Após o processamento, os dados do Grupo 1 são salvos em um arquivo HDF5.

# %%
# Processando G1
for date in paths['G1']:
    X_g1, Y_g1 = process_g1(paths['G1'][date]['X'], paths['G1'][date]['Y'])
    print(f"G1, Data: {date}, X shape: {X_g1.shape}, Y shape: {Y_g1.shape}")
    X_data.append(X_g1)
    Y_data.append(Y_g1)

# Salvando os dados processados do Grupo 1 em um arquivo HDF5
with h5py.File('/content/drive/MyDrive/data/G1_data.h5', 'w') as hf:
    hf.create_dataset('X', data=np.concatenate(X_data))
    hf.create_dataset('Y', data=np.concatenate(Y_data))
# Out:
# Corresponding Y file not found for 01-08-24_video1_00000000205000400_107880_1_x.png. Skipping...
# Total processed for group G1: 744 pairs.
# G1, Data: 01-08-2024, X shape: (744, 128, 128, 3), Y shape: (744, 128, 128, 3)
# Total processed for group G1: 613 pairs.
# G1, Data: 08-08-2024, X shape: (613, 128, 128, 3), Y shape: (613, 128, 128, 3)

# %% [markdown]
# #### Função para processar arquivos do G2
# Esta função é para o Grupo 2, onde é verificado se o arquivo de imagem X termina com `_x1`, `_x2`, `_x3`, ou `_x4`, e a correspondência é feita com o arquivo Y. Além disso, é preciso fazer o resize das imagens para poder fazer o append.

# %%
def process_g2(x_dir, y_dir):
    X_data, Y_data = [], []
    x_files = [f for f in os.listdir(x_dir) if not 'overlay' in f and ('_x1' in f or '_x2' in f or '_x3' in f or '_x4' in f)]
    y_files = [f for f in os.listdir(y_dir) if not 'overlay' in f]

    for x_file in x_files:
        # Substitui o sufixo '_x' por '_y' para encontrar o arquivo Y correspondente
        base_name = x_file.replace('_x', '_y')
        if base_name in y_files:
            y_file = base_name
            x_img = cv2.imread(os.path.join(x_dir, x_file))
            y_img = cv2.imread(os.path.join(y_dir, y_file))

            # Fazendo o resize
            target_size=(128, 128)
            x_img = cv2.resize(x_img, target_size)
            y_img = cv2.resize(y_img, target_size)

            X_data.append(x_img)
            Y_data.append(y_img)
        else:
            print(f"Corresponding Y file not found for {x_file}. Skipping...")

    print(f"Total processed for group G2: {len(X_data)} pairs.")
    return np.array(X_data), np.array(Y_data)

# %% [markdown]
# Nesta célula, processamos as imagens do Grupo 2. O processamento aqui verifica arquivos X com sufixos específicos ('x1', 'x2', etc.) e encontra correspondência com Y. Após o processamento, os dados do Grupo 2 são salvos em um arquivo HDF5.

# %%
# Processando G2
for date in paths['G2']:
    X_g2, Y_g2 = process_g2(paths['G2'][date]['X'], paths['G2'][date]['Y'])
    print(f"G2, Data: {date}, X shape: {X_g2.shape}, Y shape: {Y_g2.shape}")
    X_data.append(X_g2)
    Y_data.append(Y_g2)


# Salvando os dados processados do Grupo 2 em um arquivo HDF5
with h5py.File('/content/drive/MyDrive/data/G2_data.h5', 'w') as hf:
    hf.create_dataset('X', data=np.concatenate(X_data))
    hf.create_dataset('Y', data=np.concatenate(Y_data))
# Out:
# Total processed for group G2: 515 pairs.
# G2, Data: 06-08-2024_Video_1, X shape: (515, 128, 128, 3), Y shape: (515, 128, 128, 3)
# Total processed for group G2: 260 pairs.
# G2, Data: 29-07-2024, X shape: (260, 128, 128, 3), Y shape: (260, 128, 128, 3)

# %% [markdown]
# #### Função para processar arquivos do G3
# No Grupo 3, a correspondência é direta entre arquivos de X e Y, onde a única diferença é a substituição de `_x` por `_y`.

# %%
def process_g3(x_dir, y_dir):
    X_data, Y_data = [], []
    x_files = [f for f in os.listdir(x_dir) if not 'overlay' in f]
    y_files = [f for f in os.listdir(y_dir) if not 'overlay' in f]


    for x_file in x_files:
        base_name = x_file.replace('_x', '_y')

        # Imprimir o nome base e o nome esperado para Y
        print(f"Procurando o arquivo Y correspondente para {x_file}")
        print(f"Expected Y file: {base_name}")

        if base_name in y_files:
            print(f"Encontrou o arquivo Y correspondente: {base_name}")
            x_img = cv2.imread(os.path.join(x_dir, x_file))
            y_img = cv2.imread(os.path.join(y_dir, base_name))
            X_data.append(x_img)
            Y_data.append(y_img)
        else:
            print(f"Corresponding Y file not found for {x_file}. Skipping...")

    print(f"Total processed for group G3: {len(X_data)} pairs.")
    return np.array(X_data), np.array(Y_data)

# %% [markdown]
# Nesta célula, processamos as imagens do Grupo 3. A correspondência é direta entre os arquivos X e Y, com apenas uma substituição de sufixo. Após o processamento, os dados do Grupo 3 são salvos em um arquivo HDF5.

# %%
# Processando G3
for date in paths['G3']:
    X_g3, Y_g3 = process_g3(paths['G3'][date]['X'], paths['G3'][date]['Y'])
    print(f"G3, Data: {date}, X shape: {X_g3.shape}, Y shape: {Y_g3.shape}")
    X_data.append(X_g3)
    Y_data.append(Y_g3)

# Salvando os dados processados do Grupo 3 em um arquivo HDF5
with h5py.File('/content/drive/MyDrive/data/G3_data.h5', 'w') as hf:
    hf.create_dataset('X', data=np.concatenate(X_data))
    hf.create_dataset('Y', data=np.concatenate(Y_data))
# Out:
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0008_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0008_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0008_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0077_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0077_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0077_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0073_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0073_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0073_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0031_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0031_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0031_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0029_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0029_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0029_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0035_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0035_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0035_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0000_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0000_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0000_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0063_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0063_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0063_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0071_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0071_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0071_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0007_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0007_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0007_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0040_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0040_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0040_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0038_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0038_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0038_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0003_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0003_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0003_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0042_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0042_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0042_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0002_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0002_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0002_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0070_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0070_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0070_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0074_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0074_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0074_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0004_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0004_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0004_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0038_x3.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0038_y3.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0038_y3.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0009_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0009_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0009_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0001_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0001_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0001_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0002_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0002_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0002_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0037_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0037_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0037_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0077_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0077_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0077_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0067_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0067_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0067_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0032_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0032_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0032_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0003_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0003_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0003_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0030_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0030_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0030_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0065_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0065_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0065_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0057_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0057_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0057_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0066_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0066_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0066_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0041_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0041_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0041_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0039_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0039_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0039_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0008_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0008_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0008_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0056_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0056_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0056_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0068_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0068_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0068_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0071_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0071_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0071_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0048_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0048_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0048_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0078_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0078_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0078_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0070_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0070_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0070_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0038_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0038_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0038_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0047_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0047_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0047_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0067_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0067_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0067_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0007_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0007_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0007_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0001_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0001_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0001_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0078_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0078_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0078_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0029_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0029_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0029_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0043_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0043_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0043_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0033_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0033_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0033_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0041_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0041_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0041_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0056_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0056_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0056_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0073_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0073_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0073_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0004_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0004_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0004_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0005_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0005_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0005_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0150_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0150_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0150_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0097_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0097_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0097_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0130_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0130_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0130_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0149_x4.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0149_y4.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0149_y4.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0127_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0127_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0127_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0100_x4.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0100_y4.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0100_y4.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0085_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0085_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0085_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0146_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0146_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0146_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0103_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0103_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0103_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0148_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0148_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0148_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0095_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0095_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0095_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0149_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0149_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0149_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0094_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0094_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0094_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0146_x4.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0146_y4.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0146_y4.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0091_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0091_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0091_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0148_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0148_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0148_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0147_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0147_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0147_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0103_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0103_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0103_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0139_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0139_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0139_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0150_x3.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0150_y3.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0150_y3.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0087_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0087_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0087_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0096_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0096_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0096_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0149_x3.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0149_y3.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0149_y3.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0081_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0081_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0081_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0104_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0104_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0104_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0143_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0143_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0143_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0142_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0142_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0142_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0102_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0102_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0102_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0086_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0086_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0086_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0079_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0079_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0079_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0102_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0102_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0102_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0144_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0144_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0144_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0146_x3.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0146_y3.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0146_y3.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0094_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0094_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0094_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0095_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0095_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0095_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0102_x3.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0102_y3.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0102_y3.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0142_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0142_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0142_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0150_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0150_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0150_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0100_x3.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0100_y3.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0100_y3.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0081_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0081_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0081_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0147_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0147_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0147_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0088_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0088_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0088_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0099_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0099_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0099_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0101_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0101_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0101_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0084_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0084_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0084_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0141_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0141_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0141_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0083_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0083_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0083_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0129_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0129_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0129_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0146_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0146_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0146_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0100_x5.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0100_y5.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0100_y5.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0089_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0089_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0089_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0097_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0097_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0097_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0090_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0090_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0090_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0100_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0100_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0100_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0089_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0089_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0089_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0101_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0101_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0101_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0149_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0149_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0149_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0128_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0128_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0128_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0144_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0144_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0144_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0090_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0090_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0090_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0125_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0125_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0125_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0100_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0100_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0100_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1384_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1384_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1384_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1295_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1295_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1295_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0166_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0166_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0166_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0151_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0151_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0151_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0163_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0163_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0163_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0169_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0169_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0169_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0165_x3.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0165_y3.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0165_y3.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1342_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1342_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1342_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1348_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1348_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1348_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0154_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0154_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0154_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0217_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0217_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0217_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1333_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1333_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1333_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1295_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1295_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1295_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0153_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0153_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0153_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1348_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1348_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1348_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1294_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1294_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1294_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0165_x4.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0165_y4.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0165_y4.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1317_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1317_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1317_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1307_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1307_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1307_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0233_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0233_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0233_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0166_x3.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0166_y3.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0166_y3.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0155_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0155_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0155_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1373_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1373_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1373_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1398_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1398_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1398_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0227_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0227_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0227_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0151_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0151_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0151_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0218_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0218_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0218_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1360_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1360_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1360_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1418_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1418_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1418_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0233_x3.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0233_y3.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0233_y3.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0169_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0169_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0169_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1384_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1384_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1384_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0163_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0163_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0163_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0165_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0165_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0165_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0153_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0153_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0153_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1333_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1333_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1333_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0233_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0233_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0233_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0152_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0152_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0152_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1291_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1291_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1291_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1317_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1317_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1317_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0165_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0165_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0165_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1299_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1299_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1299_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0164_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0164_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0164_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1294_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1294_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1294_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0225_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0225_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0225_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0166_x4.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0166_y4.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0166_y4.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0152_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0152_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0152_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0166_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0166_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0166_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1423_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1423_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1423_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_0233_x4.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_0233_y4.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_0233_y4.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1398_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1398_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1398_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1547_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1547_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1547_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1552_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1552_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1552_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1541_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1541_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1541_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1564_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1564_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1564_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1457_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1457_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1457_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1529_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1529_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1529_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1592_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1592_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1592_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1550_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1550_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1550_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1578_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1578_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1578_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1527_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1527_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1527_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1546_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1546_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1546_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1477_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1477_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1477_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1590_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1590_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1590_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1571_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1571_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1571_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1621_x3.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1621_y3.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1621_y3.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1451_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1451_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1451_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1529_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1529_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1529_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1596_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1596_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1596_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1551_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1551_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1551_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1621_x2.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1621_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1621_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1566_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1566_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1566_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1475_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1475_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1475_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1626_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1626_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1626_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000199000400_frame_1621_x1.png
# Expected Y file: 30-07-24_video_00000000199000400_frame_1621_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000199000400_frame_1621_y1.png
# ...
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5391_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5391_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5391_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5626_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5626_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5626_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5419_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5419_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5419_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5393_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5393_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5393_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5440_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5440_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5440_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5389_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5389_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5389_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5409_x2.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5409_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5409_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5406_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5406_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5406_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5401_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5401_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5401_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5470_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5470_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5470_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5420_x2.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5420_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5420_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5619_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5619_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5619_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5557_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5557_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5557_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5393_x3.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5393_y3.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5393_y3.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5436_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5436_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5436_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5490_x2.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5490_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5490_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5643_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5643_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5643_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5439_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5439_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5439_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5449_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5449_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5449_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5624_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5624_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5624_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5524_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5524_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5524_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5411_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5411_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5411_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5411_x2.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5411_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5411_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5613_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5613_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5613_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5480_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5480_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5480_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5426_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5426_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5426_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5451_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5451_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5451_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5485_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5485_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5485_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5399_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5399_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5399_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5648_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5648_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5648_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5622_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5622_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5622_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5450_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5450_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5450_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5490_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5490_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5490_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5524_x3.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5524_y3.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5524_y3.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5425_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5425_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5425_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5392_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5392_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5392_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5524_x2.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5524_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5524_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5446_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5446_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5446_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5513_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5513_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5513_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5639_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5639_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5639_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5474_x2.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5474_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5474_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5417_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5417_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5417_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5513_x2.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5513_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5513_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5420_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5420_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5420_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5639_x2.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5639_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5639_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5475_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5475_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5475_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5440_x2.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5440_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5440_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5393_x2.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5393_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5393_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5649_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5649_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5649_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5661_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5661_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5661_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5664_x2.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5664_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5664_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5699_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5699_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5699_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5696_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5696_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5696_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5699_x2.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5699_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5699_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5655_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5655_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5655_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5667_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5667_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5667_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5649_x2.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5649_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5649_y2.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5662_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5662_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5662_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5684_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5684_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5684_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5669_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5669_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5669_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5664_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5664_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5664_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5668_x1.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5668_y1.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5668_y1.png
# Procurando o arquivo Y correspondente para 30-07-24_video_00000000205000000_frame_5684_x2.png
# Expected Y file: 30-07-24_video_00000000205000000_frame_5684_y2.png
# Encontrou o arquivo Y correspondente: 30-07-24_video_00000000205000000_frame_5684_y2.png
# Total processed for group G3: 724 pairs.
# G3, Data: 30-07-2024, X shape: (724, 128, 128, 3), Y shape: (724, 128, 128, 3)

# %% [markdown]
# #### Função para processar arquivos do G4
# Semelhante ao Grupo 3, mas específico para a nomenclatura do Grupo 4.

# %%
def process_g4(x_dir, y_dir):
    X_data, Y_data = [], []
    x_files = [f for f in os.listdir(x_dir) if not 'overlay' in f]
    y_files = [f for f in os.listdir(y_dir) if not 'overlay' in f]

    for x_file in x_files:
        y_file = x_file.replace('_x', '_y')

        if y_file in y_files:
            x_img = cv2.imread(os.path.join(x_dir, x_file))
            y_img = cv2.imread(os.path.join(y_dir, y_file))
            X_data.append(x_img)
            Y_data.append(y_img)

    return np.array(X_data), np.array(Y_data)

# %% [markdown]
# Nesta célula, processamos as imagens do Grupo 4. A correspondência entre X e Y é muito clara, com substituição simples do sufixo. Após o processamento, os dados do Grupo 4 são salvos em um arquivo HDF5.

# %%
# Processando G4
X_g4, Y_g4 = process_g4(paths['G4']['02-08-2024']['X'], paths['G4']['02-08-2024']['Y'])
print(f"G4, Data: 02-08-2024, X shape: {X_g4.shape}, Y shape: {Y_g4.shape}")
X_data.append(X_g4)
Y_data.append(Y_g4)

# Salvando os dados processados do Grupo 4 em um arquivo HDF5
with h5py.File('/content/drive/MyDrive/data/G4_data.h5', 'w') as hf:
    hf.create_dataset('X', data=np.concatenate(X_data))
    hf.create_dataset('Y', data=np.concatenate(Y_data))
# Out:
# G4, Data: 02-08-2024, X shape: (843, 128, 128, 3), Y shape: (843, 128, 128, 3)

# %% [markdown]
# #### Verificação dos shapes das pastas com condições
# Verificamos as dimensões das imagens X e Y em cada uma das pastas para garantir que elas tenham as mesmas dimensões. Esse passo é importante para garantir a compatibilidade durante o treinamento do modelo.

# %% [markdown]
# ### Salvando em um conjunto de dados
# Aqui, os dados processados e verificados são salvos em um arquivo HDF5, que é um formato de armazenamento eficiente, especialmente útil para grandes volumes de dados, permitindo carregamento rápido para futuras análises.

# %%
# Salvando o conjunto de dados combinado de todos os grupos
with h5py.File('/content/drive/MyDrive/data/combined_data.h5', 'w') as hf:
    hf.create_dataset('X', data=np.concatenate([X_g1, X_g2, X_g3, X_g4]))
    hf.create_dataset('Y', data=np.concatenate([Y_g1, Y_g2, Y_g3, Y_g4]))
