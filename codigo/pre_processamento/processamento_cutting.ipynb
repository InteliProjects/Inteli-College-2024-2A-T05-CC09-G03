# %% [markdown]
# # Processamento de Imagens - Cutting
#
# Este notebook tem como objetivo processar as imagens anotadas no CVAT e aplicar as máscaras nas áreas específicas dos frames, redimensionando as imagens para o formato desejado. Este é o segundo passo no pipeline, onde, após as máscaras serem geradas manualmente, o código converte as anotações XML em imagens processadas.
#
#
# ## Garantia da Diversidade
# Garantir a diversidade das imagens foi uma prioridade durante todo o processo. Para evitar redundância, não utilizamos frames sequenciais e selecionamos frames com intervalos que capturam variações significativas no cenário e nos contextos dos vídeos. Abaixo, listamos alguns exemplos de diversidade capturada nos vídeos térmicos:
#
# 1. **Diversidade de Cor dos Bois:** Os vídeos capturam bois com diferentes cores, incluindo brancos, pretos e manchas variadas, o que é visível mesmo nas imagens térmicas.
# 2. **Temperaturas Corporais Diferentes:** Variações térmicas nas imagens devido a diferenças de temperatura entre os bovinos, possivelmente devido a diferentes níveis de atividade física ou estados de saúde.
# 3. **Variação de Posições:** Captura de olhos em diferentes ângulos e posições, como de frente, de lado ou parcialmente cobertos.
# 4. **Ambiente e Iluminação:** Imagens foram capturadas sob diferentes condições de iluminação, incluindo luz direta, sombras, e reflexos no ambiente térmico.
# 5. **Estado dos Bovinos:** Imagens capturam diferentes estados dos bovinos, como alerta, descansando, com os olhos parcialmente fechados ou totalmente abertos.

# %% [markdown]
# ## Processamento e Recorte de Imagens com Anotações XML

# %% [markdown]
# A seguir, vamos detalhar o processo de recorte e manipulação de imagens com base em anotações fornecidas em arquivos XML. Usaremos bibliotecas populares como PIL, cv2, os, e xml.etree.ElementTree para manipulação de imagens e parsing de XML.

# %% [markdown]
# ### Importação das Bibliotecas Necessárias

# %% [markdown]
# - os: Usada para interagir com o sistema de arquivos, como verificar a existência de diretórios e criar novos.
# - xml.etree.ElementTree: Utilizada para parsear e navegar em arquivos XML, permitindo extrair as anotações das imagens.
# - PIL (Python Imaging Library): Fornece funcionalidades para carregar, manipular e salvar imagens.
# - cv2: Parte do OpenCV, é usada aqui para redimensionar as imagens recortadas.
# - numpy (np): Útil para conversão entre imagens PIL e arrays NumPy, especialmente durante operações de redimensionamento.

# %%
import os
import xml.etree.ElementTree as ET
from PIL import Image, ImageDraw
import cv2
import numpy as np

# %% [markdown]
# ### Configuração dos Diretórios e Arquivos

# %%
frame_subfolders = [
    {'folder': 'subpasta_1', 'xml': 'annotations_1.xml', 'video_code': '00000000199000400'},
    {'folder': 'subpasta_2', 'xml': 'annotations_2.xml', 'video_code': '00000000199000400'},
    {'folder': 'subpasta_3', 'xml': 'annotations_3.xml', 'video_code': '00000000199000400'},
    {'folder': 'subpasta_4', 'xml': 'annotations_4.xml', 'video_code': '00000000199000400'},
    {'folder': 'subpasta_5', 'xml': 'annotations_5.xml', 'video_code': '00000000205000000'}
]

# %% [markdown]
# - **frame_subfolders**: Lista de dicionários que armazena informações sobre as subpastas de frames e seus respectivos arquivos XML de anotações. Cada item inclui:
#     - **folder**: Nome da subpasta contendo os frames a serem processados.
#     - **xml**: Nome do arquivo XML contendo as anotações para os frames na subpasta correspondente.
#     - **video_code**: Código do vídeo associado aos frames, usado para nomear os arquivos de saída.

# %% [markdown]
# ### Criação do Diretório de Saída

# %% [markdown]
# - O código verifica se o diretório de saída já existe. Se não, ele o cria e exibe uma mensagem de sucesso.

# %%
output_base_folder = 'labels_agrupado'
if not os.path.exists(output_base_folder):
    os.makedirs(output_base_folder)
    print(f"Pasta {output_base_folder} criada com sucesso.")

# %% [markdown]
# - **output_base_folder**: Define o diretório base onde as imagens processadas serão salvas.

# %% [markdown]
# ### **Processamento de Imagens com Base em Anotações XML**
#
# A seguir, iremos iterar sobre subpastas contendo frames de vídeo e seus respectivos arquivos XML de anotações. O objetivo é:
#
# 1. **Verificar a existência das pastas e arquivos XML**: Garantimos que tanto os frames quanto as anotações estão disponíveis antes de prosseguir.
# 2. **Ajustar os IDs das imagens com base nos offsets**: Cada subpasta pode começar em um frame diferente do vídeo, então ajustamos os IDs das imagens para garantir que eles correspondam corretamente ao frame original.
# 3. **Carregar as imagens e anotações**: As imagens são carregadas a partir dos arquivos de frames, e as anotações são extraídas do arquivo XML correspondente.
# 4. **Recortar e redimensionar as regiões de interesse (contextos)**: Usamos as coordenadas das caixas delimitadoras no XML para recortar partes específicas das imagens (denominadas "contextos") e redimensioná-las para um tamanho padrão de 128x128 pixels.
# 5. **Desenhar elementos dentro dos contextos**: Para cada "contexto" recortado, desenhamos as regiões correspondentes a "cabeças" e "olhos" para criar novas imagens anotadas, que podem ser usadas em modelos de IA.
# 6. **Salvar os resultados**: Tanto os contextos recortados e redimensionados quanto as imagens finais com as anotações desenhadas são salvos em diretórios específicos.
#
# Este processo é repetido para cada subpasta e cada imagem dentro das subpastas, garantindo que todas as anotações sejam aplicadas corretamente aos frames correspondentes.

# %%
# Itera sobre cada subpasta de frames e seu respectivo XML
for idx, subfolder_info in enumerate(frame_subfolders):

    frames_folder = subfolder_info['folder']
    xml_file = subfolder_info['xml']
    video_code = subfolder_info['video_code']
    
    # Verifica se a subpasta e o arquivo XML existem
    if not os.path.exists(frames_folder) or not os.path.exists(xml_file):
        print(f"frames_folder: {frames_folder}")
        print(f"xml_file: {xml_file}")
        print(f"Pasta {frames_folder} ou arquivo {xml_file} não encontrado. Pulando.")
        break
    
    
    # Define o diretório de saída para a subpasta atual
    output_folder = os.path.join(output_base_folder)
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
        print(f"Pasta {output_folder} criada com sucesso.")

    # Parseia o arquivo XML correspondente
    tree = ET.parse(xml_file)
    root = tree.getroot()
    print(root)

    # Percorre todas as imagens descritas no XML
    for image_info in root.findall('.//image'):
        image_name = image_info.get('name')

        # Verifica se a imagem existe na pasta
        image_path = os.path.join(frames_folder, image_name)
        # print(f"Tentando acessar o arquivo: {image_path}")  # Para depuração
        if not os.path.exists(image_path):
            print(f"Imagem {image_name} não encontrada na pasta {frames_folder}. Pulando para a próxima.")
            continue

        # Carrega a imagem
        image = Image.open(image_path)

        # Contador para múltiplos contextos
        contexto_counter = 1

        # Percorre as caixas delimitadoras no XML
        for box in image_info.findall('box'):
            label = box.get('label')

            if label == "contexto":
                contexto_coords = (
                    float(box.get('xtl')),
                    float(box.get('ytl')),
                    float(box.get('xbr')),
                    float(box.get('ybr'))
                )
                cropped_image = image.crop(contexto_coords)
                
                # Redimensiona a imagem para 128x128 pixels usando OpenCV
                cropped_image_np = np.array(cropped_image)  # Converte para array NumPy
                resized_image_np = cv2.resize(cropped_image_np, (128, 128), interpolation=cv2.INTER_AREA)  # Redimensiona
                resized_image = Image.fromarray(resized_image_np)  # Converte de volta para imagem PIL

                image_name_no_ext = os.path.splitext(image_name)[0]

                cropped_image_path = os.path.join(output_folder, f"30-07-24_video_{video_code}_{image_name_no_ext}_x{contexto_counter}.png")
                resized_image.save(cropped_image_path)
                print(f"Contexto {contexto_counter} foi salvo e redimensionado para 128x128 pixels.")

                # Preparar para desenhar os elementos dentro do contexto
                contexto_width = int(contexto_coords[2] - contexto_coords[0])
                contexto_height = int(contexto_coords[3] - contexto_coords[1])
                result_image = Image.new('RGB', (contexto_width, contexto_height), (0, 0, 0))  # 'RGB' modo para cores

                draw = ImageDraw.Draw(result_image)

                # Percorrer novamente as caixas para desenhar as cabeças primeiro
                for inner_box in image_info.findall('box'):
                    inner_label = inner_box.get('label')

                    if inner_label == "cabeca":
                        cabeca_coords = (
                            float(inner_box.get('xtl')),
                            float(inner_box.get('ytl')),
                            float(inner_box.get('xbr')),
                            float(inner_box.get('ybr'))
                        )
                        relative_cabeca_coords = (
                            cabeca_coords[0] - contexto_coords[0],
                            cabeca_coords[1] - contexto_coords[1],
                            cabeca_coords[2] - contexto_coords[0],
                            cabeca_coords[3] - contexto_coords[1]
                        )
                        draw.rectangle(relative_cabeca_coords, fill=(255, 255, 255))

                # Depois, desenhar os olhos para garantir que eles fiquem por cima
                for inner_box in image_info.findall('box'):
                    inner_label = inner_box.get('label')

                    if inner_label == "olho":
                        olho_coords = (
                            float(inner_box.get('xtl')),
                            float(inner_box.get('ytl')),
                            float(inner_box.get('xbr')),
                            float(inner_box.get('ybr'))
                        )
                        relative_olho_coords = (
                            olho_coords[0] - contexto_coords[0],
                            olho_coords[1] - contexto_coords[1],
                            olho_coords[2] - contexto_coords[0],
                            olho_coords[3] - contexto_coords[1]
                        )
                        draw.rectangle(relative_olho_coords, fill=(255, 0, 0))
                #06-08-24_video2_imagem_termica2-edit_12454_y1.
                result_image = np.array(result_image)  # Converte para array NumPy
                result_image = cv2.resize(result_image, (128, 128), interpolation=cv2.INTER_AREA)  # Redimensiona
                result_image = Image.fromarray(result_image)  # Converte de volta para imagem PIL

                result_image_path = os.path.join(output_folder, f"30-07-24_video_{video_code}_{image_name_no_ext}_y{contexto_counter}.png")
                result_image.save(result_image_path)
                print(f"Imagem result.png para contexto {contexto_counter} gerada com sucesso.")

                contexto_counter += 1
# Out:
# <Element 'annotations' at 0x000001D06FA348B0>
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 3 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 3 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 3 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 3 gerada com sucesso.
# Contexto 4 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 4 gerada com sucesso.
# Contexto 5 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 5 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 3 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 3 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 3 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 3 gerada com sucesso.
# Contexto 4 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 4 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 3 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 3 gerada com sucesso.
# Contexto 4 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 4 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 3 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 3 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 3 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 3 gerada com sucesso.
# Contexto 4 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 4 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 3 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 3 gerada com sucesso.
# Contexto 4 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 4 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 3 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 3 gerada com sucesso.
# Contexto 4 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 4 gerada com sucesso.
# <Element 'annotations' at 0x000001D06FA936A0>
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 3 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 3 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 2 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 2 gerada com sucesso.
# Contexto 3 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 3 gerada com sucesso.
# Contexto 4 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 4 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# <Element 'annotations' at 0x000001D07011AA70>
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# Imagem result.png para contexto 1 gerada com sucesso.
# Contexto 1 foi salvo e redimensionado para 128x128 pixels.
# ...
# Imagem frame_6442.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6443.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6444.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6445.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6446.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6447.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6448.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6449.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6450.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6451.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6452.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6453.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6454.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6455.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6456.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6457.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6458.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6459.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6460.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6461.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6462.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6463.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6464.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6465.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6466.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6467.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6468.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6469.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6470.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6471.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6472.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6473.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6474.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6475.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6476.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6477.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6478.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6479.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6480.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6481.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6482.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6483.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6484.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6485.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6486.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6487.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6488.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6489.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6490.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6491.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6492.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6493.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6494.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6495.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6496.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6497.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6498.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6499.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6500.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6501.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6502.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6503.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6504.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6505.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6506.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6507.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6508.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6509.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6510.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6511.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6512.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6513.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6514.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6515.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6516.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6517.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6518.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6519.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6520.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6521.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6522.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6523.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6524.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6525.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6526.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6527.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6528.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6529.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6530.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6531.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6532.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6533.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6534.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6535.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6536.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6537.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6538.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6539.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6540.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6541.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6542.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6543.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6544.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6545.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6546.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6547.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6548.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6549.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6550.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6551.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6552.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6553.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6554.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6555.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6556.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6557.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6558.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6559.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6560.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6561.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6562.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6563.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6564.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6565.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6566.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6567.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6568.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6569.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6570.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6571.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6572.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6573.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6574.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6575.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6576.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6577.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6578.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6579.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6580.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6581.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6582.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6583.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6584.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6585.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6586.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6587.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6588.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6589.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6590.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6591.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6592.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6593.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6594.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6595.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6596.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6597.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6598.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6599.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6600.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6601.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6602.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6603.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6604.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6605.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6606.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6607.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6608.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6609.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6610.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6611.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6612.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6613.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6614.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6615.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6616.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6617.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6618.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6619.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6620.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6621.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6622.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6623.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6624.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6625.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6626.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6627.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6628.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6629.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6630.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6631.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6632.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6633.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6634.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6635.png não encontrada na pasta subpasta_5. Pulando para a próxima.
# Imagem frame_6636.png não encontrada na pasta subpasta_5. Pulando para a próxima.
